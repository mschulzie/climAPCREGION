# %% [markdown]
# Dear participants of CLIMAPCREGION SoSe2023
#
# thanks for handing in the links to your online repositories.  Please take your time to review and familiarize yousrself with the code of your fellow students to understand the error handling and methods applied in their code.  Please check that your code is included and the link is correct.
#
# Find below the table with the links to the algorithms. You may use these for the 2nd part of this exercise. This will safe you time and enable you to make more progress.
#
# The assignment of climate indices was unfortunately delayed due to my limited internet access in the end of last week and will be done today. The hand in times will be adjusted accordingly.
#
# best regards,
#
# Sunke Schmidtko
#
#
#
# Name / Method / Linke
#
# V. Volkova
# LSF / OI
# https://github.com/vvvalukha/climAPC
#
#
# Q Cunningham
# Wavelett
# https://github.com/quinn305/ClimAPC-Wavelets/tree/main
#
#
# T. Knoop
# (S)ARIMA
# https://github.com/tcknoop/climAPC_ARIMA.git
#
#
# A.Andrae
# ARIMA
# https://github.com/AlexAndrae7/ARIMA_model.git
#
#
# F. Kirch
# Wavelett
# https://github.com/felixkirch/apc-region
#
#
# C. Posern
# EOF
# https://github.com/ConnyPosern/EOF
#
#
# L Aroucha
# LSF / OI
# https://github.com/leoaroucha/climAPCREGION-01a
#
#
# M Pohl
# LSF /OI
# https://github.com/math1sebp/climAPCREGION-least-square-and-interpolation
#
#
# M. Schulzie
# EOF
# https://github.com/mschulzie/climAPCREGION
#
#
# C. Ziska
# FFT
# Offline file – see DL folder.
